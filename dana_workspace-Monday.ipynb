# %%
# Example Feature Extraction from XML Files
# We count the number of specific system calls made by the programs, and use
# these as our features.

# This code requires that the unzipped training set is in a folder called "train". 
import os
from collections import Counter
try:
    import xml.etree.cElementTree as ET
except ImportError:
    import xml.etree.ElementTree as ET
import numpy as np
from scipy import sparse
import pandas as pd
import pickle
import io
from sklearn import grid_search
from sklearn import mixture

import util

# %% [markdown]
# ## Feature Extraction

# %%
TRAIN_DIR = "train"
TEST_DIR = "test"

call_set = pickle.load(open( "call_set.p", "rb" ))

# %%
call_set_nonredundant = set(call_set) - set(["processes", "all_section"])

# %%
#
def add_to_set(tree):
    for el in tree.iter():
        call = el.tag
        call_set.add(call)

def create_data_matrix(start_index, end_index, direc="train"):
    X = None
    classes = []
    ids = [] 
    i = -1
    for datafile in os.listdir(direc):
        if datafile == '.DS_Store':
            continue

        i += 1
        if i < start_index:
            continue 
        if i >= end_index:
            break

        # extract id and true class (if available) from filename
        id_str, clazz = datafile.split('.')[:2]
        ids.append(id_str)
        # add target class if this is training data
        try:
            classes.append(util.malware_classes.index(clazz))

        except ValueError:
            # we should only fail to find the label in our list of malware classes
            # if this is test data, which always has an "X" label
            assert clazz == "X"
            classes.append(-1)

        # parse file as an xml document
        tree = ET.parse(os.path.join(direc,datafile))
        # add_to_set(tree)
        this_row = call_feats(tree)
        if X is None:
            X = this_row 
        else:
            X = np.vstack((X, this_row))

    return X, np.array(classes), ids

def call_feats(tree):
    good_calls = list(call_set_nonredundant)
    call_counter = {}
    total_calls = 0
    n_success, success_denom = 0.0,0.0
    for el in tree.iter():
        call = el.tag
        if el.attrib.has_key('successful'):
            success_denom += 1
            n_success += int(el.attrib['successful'])
        total_calls += 1
        if call not in call_counter:
            call_counter[call] = 1
        else:
            call_counter[call] += 1
    unq_calls = len(call_counter.keys())
    percentage_success = n_success / success_denom
            
    call_feat_array = np.zeros(len(good_calls))
    for i in range(len(good_calls)):
        call = good_calls[i]
        call_feat_array[i] = 0
        if call in call_counter:
            call_feat_array[i] = call_counter[call]
    #print total_calls, unq_calls, percentage_success, success_denom, n_success
    call_feat_array = np.append(call_feat_array, [total_calls, unq_calls, percentage_success])
    
    return call_feat_array

# %%
## Feature extraction
def main():
    # SAVE TRAINING DATA
    '''
    X_train, t_train, train_ids = create_data_matrix(0, 3086, direc=TRAIN_DIR)
    X_train = pd.DataFrame(X_train)
    t_train = pd.DataFrame(t_train, columns=['class'])
    train_ids = pd.DataFrame(train_ids,columns=['id'])
          
    filename1 = 'X_train.p'
    filename2 = 't_train.p'
    filename3 = 'train_ids.p'
    
    pickle.dump(X_train, io.open(filename1, 'wb'))
    pickle.dump(t_train, io.open(filename2, 'wb'))
    pickle.dump(train_ids, io.open(filename3, 'wb'))
    
    '''    
    # SAVE TESTING DATA
    X_test, t_test, test_ids = create_data_matrix(0, 3724, direc=TEST_DIR)
    X_test = pd.DataFrame(X_test)
    test_ids = pd.DataFrame(test_ids,columns=['id'])
    
    filename4 = 'X_test.p'
    filename5 = 't_test.p'
    filename6 = 'test_ids.p'
    
    pickle.dump(X_test, io.open(filename4, 'wb'))
    pickle.dump(t_test, io.open(filename5, 'wb'))
    pickle.dump(test_ids, io.open(filename6, 'wb'))

# %%
if __name__ == "__main__":
    main()
# Out:
#   File "<string>", line unknown
# ParseError: unclosed token: line 4971, column 0

# %% [markdown]
# ## Data Modeling

# %%
X_train = pickle.load(open( "X_train.p", "rb" ))
t_train = pickle.load(open( "t_train.p", "rb" ))
train_ids = pickle.load(open( "train_ids.p", "rb" ))

"""
X_test = pickle.load(open("X_test.p", "rb"))
t_test = pickle.load(open( "t_test.p", "rb" ))
test_ids = pickle.load(open( "test_ids.p", "rb" ))
"""
# Out:
# '\nX_test = pickle.load(open("X_test.p", "rb"))\nt_test = pickle.load(open( "t_test.p", "rb" ))\ntest_ids = pickle.load(open( "test_ids.p", "rb" ))\n'

# %%
"""
X_train = pickle.load(open( "X_train.p", "rb" ))
t_train = pickle.load(open( "t_train.p", "rb" ))
train_ids = pickle.load(open( "train_ids.p", "rb" ))

"""
X_test = pd.read_pickle("X_test.p")
t_test = pickle.load(open( "t_test.p", "rb" ))
test_ids = pd.read_pickle( "test_ids.p" )

# %% [markdown]
# ## Change data

# %%
t_train_squeezed = np.squeeze(np.asarray(t_train))
X_train_array = np.asarray(X_train)

# %%
mixture.GMM()

# %% [markdown]
# ##GMM

# %%
# Create a way to determine which GMM parameters are best
# Note that we had to do this because the grid_search will not work for GMM because score returns an array
# Instead we decided to use AIC and BIC
# This averages the AIC and BIC from the same model with different random_states so we could choose the "best model"
def GMMavg(gmm, n_iter, X, t):
    AIC_array = []
    BIC_array = []
    for i in range(n_iter):
        gmm_iter_i = gmm
        gmm_iter_i = gmm.fit(X, t)
        AIC_array.append(gmm_iter_i.aic(X))
        BIC_array.append(gmm_iter_i.bic(X))
    return np.mean(AIC_array), np.mean(BIC_array)

# %%
GMMavg(mixture.GMM(n_components=14,covariance_type='diag', n_iter=1000, random_state=None), 25, X_train_array, t_train_squeezed)
# Out:
# (569054.42432612833, 587212.629104194)

# %%
GMMavg(mixture.GMM(n_components=14,covariance_type='full', n_iter=1000, random_state=None), 25, X_train_array, t_train_squeezed)
# Out:
# (642539.26815047557, 1139810.9691564385)

# %%
GMMavg(mixture.GMM(n_components=14,covariance_type='spherical', n_iter=1000, random_state=None), 25, X_train_array, t_train_squeezed)
# Out:
# (3414361.7436124687, 3423564.5559376762)

# %%
GMMavg(mixture.GMM(n_components=14,covariance_type='tied', n_iter=1000, random_state=None), 25, X_train_array, t_train_squeezed)
# Out:
# (1417041.4782957423, 1461027.903894719)

# %%
GMMavg(mixture.GMM(n_components=14,covariance_type='diag', n_iter=10000, random_state=None, min_covar=0.0000001), 25, X_train_array, t_train_squeezed)
# Out:
# (-467519.52244008018, -449361.31766201457)

# %%
gmm_test = mixture.GMM(n_components=14,covariance_type='diag', n_iter=100000, random_state=None, min_covar=0.0000000001)

# %%
skf = StratifiedKFold(t_train_squeezed, n_folds=5, shuffle=True)
# Code credit: http://scikit-learn.org/stable/auto_examples/mixture/plot_gmm_classifier.html

train_index, test_index = next(iter(skf))
X_train1 = X_train_array[train_index]
y_train1 = t_train_squeezed[train_index]
X_test1 = X_train_array[test_index]
y_test1 = t_train_squeezed[test_index]

train_index
# Out:
# array([   0,    1,    2, ..., 3082, 3083, 3084])

# %%
i = 1
print "data observation: %s" % i
print "actual class: %s" % t_train_squeezed[i]
print "prediction: %s" % gmm_test.predict(np.asarray(X_train))[i]
print "data probability predictions: %s" % gmm_test.predict_proba(np.asarray(X_train))[i]
print "log of probability predictions: %s" % np.log(gmm_test.predict_proba(np.asarray(X_train)))[i]
print "score from GMM.score: %s" % gmm_test.score(np.asarray(X_train))[i]
print "AIC: %s" % gmm_test.aic(X_train_array)
print "BIC: %s" % gmm_test.bic(X_train_array)
# Out:
# data observation: 1
# actual class: 6
# prediction: 1
# data probability predictions: [  0.00000000e+000   1.00000000e+000   0.00000000e+000   0.00000000e+000
#    0.00000000e+000   0.00000000e+000   0.00000000e+000   0.00000000e+000
#    2.74722721e-163   0.00000000e+000   0.00000000e+000   0.00000000e+000
#    0.00000000e+000   0.00000000e+000]
# log of probability predictions: [         -inf    0.                  -inf          -inf          -inf
#           -inf          -inf          -inf -374.31077804          -inf
#           -inf          -inf          -inf          -inf]
# score from GMM.score: -99.1689138884
# AIC: -103489.204112
# BIC: -85330.9993336

# %% [markdown]
# ## GMM using Cross Validation

# %%
string = 'test'
str(2)
# Out:
# '2'

# %%
classifiers = dict((covar_type+str(random_state), mixture.GMM(n_components=14, random_state=random_state,
                    covariance_type=covar_type, n_iter=100, min_covar = 0.0000001))
                   for covar_type in ['spherical', 'diag', 'tied', 'full']
                   for random_state in range(3))

# %%
# Code credit: http://scikit-learn.org/stable/auto_examples/mixture/plot_gmm_classifier.html

# Split 
from sklearn.cross_validation import StratifiedKFold
skf = StratifiedKFold(t_train_squeezed, n_folds=5, shuffle=True, random_state=3)

'''
train_index, test_index = next(iter(skf))
X_train1 = X_train_array[train_index]
y_train1 = t_train_squeezed[train_index]
X_test1 = X_train_array[test_index]
y_test1 = t_train_squeezed[test_index]
'''

classifiers = dict((covar_type+str(random_state), mixture.GMM(n_components=14, random_state=random_state,
                    covariance_type=covar_type, n_iter=100, min_covar = 0.0000001))
                   for covar_type in ['spherical', 'diag', 'tied', 'full']
                   for random_state in range(50))

# Loop over classifiers
for index, (name, classifier) in enumerate(classifiers.items()):
    
    i = 1
    
    # Loop over k-folds
    for train_index, test_index in skf:
        
        train_accuracy = []
        test_accuracy = []
    
        X_train_k, X_test_k = X_train_array[train_index], X_train_array[test_index]
        y_train_k, y_test_k = t_train_squeezed[train_index], t_train_squeezed[test_index]
    
        classifier.fit(X_train_k,y_train_k)
        y_train_pred = classifier.predict(X_train_k)

        x = (np.mean(y_train_pred.ravel() == y_train_k.ravel()) * 100)
        train_accuracy.append(x)
        #print 'Train accuracy for %s %s: %.2f' % (name, i, x)

        y_test_pred = classifier.predict(X_test_k)
        y = (np.mean(y_test_pred.ravel() == y_test_k.ravel()) * 100)
        test_accuracy.append(y)
        #print 'Test accuracy for %s %s: %.2f' % (name, i, y)
        
        i += 1

        #print 'Converged? %s' % classifier.converged_      
    
    print 'MEAN Train accuracy for %s: %.2f' % (name, np.mean(train_accuracy))
    print 'MEAN Test accuracy for %s: %.2f' % (name, np.mean(test_accuracy))
# Out:
# MEAN Train accuracy for tied48: 5.29
# MEAN Test accuracy for tied48: 4.91
# MEAN Train accuracy for tied49: 1.09
# MEAN Test accuracy for tied49: 1.31
# MEAN Train accuracy for full21: 3.39
# MEAN Test accuracy for full21: 3.60
# MEAN Train accuracy for full20: 3.35
# MEAN Test accuracy for full20: 3.76
# MEAN Train accuracy for full27: 2.95
# MEAN Test accuracy for full27: 3.60
# MEAN Train accuracy for full26: 7.23
# MEAN Test accuracy for full26: 9.33
# MEAN Train accuracy for full25: 4.40
# MEAN Test accuracy for full25: 4.42
# MEAN Train accuracy for full22: 8.81
# MEAN Test accuracy for full22: 9.82
# MEAN Train accuracy for tied40: 2.91
# MEAN Test accuracy for tied40: 3.60
# MEAN Train accuracy for tied41: 3.07
# MEAN Test accuracy for tied41: 3.44
# MEAN Train accuracy for tied42: 5.86
# MEAN Test accuracy for tied42: 4.91
# MEAN Train accuracy for tied43: 2.67
# MEAN Test accuracy for tied43: 3.44
# MEAN Train accuracy for tied44: 3.31
# MEAN Test accuracy for tied44: 3.93
# MEAN Train accuracy for tied45: 8.04
# MEAN Test accuracy for tied45: 9.17
# MEAN Train accuracy for tied46: 2.42
# MEAN Test accuracy for tied46: 2.95
# MEAN Train accuracy for tied47: 2.75
# MEAN Test accuracy for tied47: 3.11
# MEAN Train accuracy for full0: 1.94
# MEAN Test accuracy for full0: 2.29
# MEAN Train accuracy for full1: 3.03
# MEAN Test accuracy for full1: 3.60
# MEAN Train accuracy for full2: 3.27
# MEAN Test accuracy for full2: 3.60
# MEAN Train accuracy for full3: 3.35
# MEAN Test accuracy for full3: 3.60
# MEAN Train accuracy for full4: 4.44
# MEAN Test accuracy for full4: 4.42
# MEAN Train accuracy for full5: 2.79
# MEAN Test accuracy for full5: 1.96
# MEAN Train accuracy for full6: 2.83
# MEAN Test accuracy for full6: 3.60
# MEAN Train accuracy for full7: 2.99
# MEAN Test accuracy for full7: 3.60
# MEAN Train accuracy for full8: 3.15
# MEAN Test accuracy for full8: 2.95
# MEAN Train accuracy for full9: 7.60
# MEAN Test accuracy for full9: 9.33
# MEAN Train accuracy for full24: 1.33
# MEAN Test accuracy for full24: 1.15
# MEAN Train accuracy for full29: 4.00
# MEAN Test accuracy for full29: 4.42
# MEAN Train accuracy for full28: 2.99
# MEAN Test accuracy for full28: 3.60
# MEAN Train accuracy for tied30: 2.99
# MEAN Test accuracy for tied30: 3.60
# MEAN Train accuracy for spherical1: 10.67
# MEAN Test accuracy for spherical1: 9.82
# MEAN Train accuracy for spherical0: 2.63
# MEAN Test accuracy for spherical0: 2.45
# MEAN Train accuracy for spherical3: 2.95
# MEAN Test accuracy for spherical3: 3.27
# MEAN Train accuracy for spherical2: 2.30
# MEAN Test accuracy for spherical2: 2.13
# MEAN Train accuracy for spherical5: 1.21
# MEAN Test accuracy for spherical5: 1.31
# MEAN Train accuracy for spherical4: 4.77
# MEAN Test accuracy for spherical4: 3.60
# MEAN Train accuracy for spherical7: 2.71
# MEAN Test accuracy for spherical7: 2.45
# MEAN Train accuracy for spherical6: 2.95
# MEAN Test accuracy for spherical6: 2.78
# MEAN Train accuracy for spherical9: 12.08
# MEAN Test accuracy for spherical9: 10.97
# MEAN Train accuracy for spherical8: 1.41
# MEAN Test accuracy for spherical8: 1.64
# MEAN Train accuracy for tied33: 2.30
# MEAN Test accuracy for tied33: 0.98
# MEAN Train accuracy for tied32: 2.30
# MEAN Test accuracy for tied32: 3.11
# MEAN Train accuracy for full45: 7.84
# MEAN Test accuracy for full45: 9.33
# MEAN Train accuracy for full44: 2.30
# MEAN Test accuracy for full44: 2.45
# MEAN Train accuracy for full47: 1.82
# MEAN Test accuracy for full47: 2.45
# MEAN Train accuracy for full46: 1.98
# MEAN Test accuracy for full46: 2.45
# MEAN Train accuracy for full41: 3.07
# MEAN Test accuracy for full41: 3.60
# MEAN Train accuracy for full40: 2.22
# MEAN Test accuracy for full40: 2.45
# MEAN Train accuracy for full43: 1.98
# MEAN Test accuracy for full43: 2.45
# MEAN Train accuracy for full42: 6.34
# MEAN Test accuracy for full42: 5.73
# MEAN Train accuracy for full49: 0.48
# MEAN Test accuracy for full49: 0.49
# MEAN Train accuracy for full48: 5.17
# MEAN Test accuracy for full48: 5.89
# MEAN Train accuracy for tied34: 1.78
# MEAN Test accuracy for tied34: 0.82
# MEAN Train accuracy for tied37: 1.66
# MEAN Test accuracy for tied37: 0.82
# MEAN Train accuracy for tied22: 8.24
# MEAN Test accuracy for tied22: 8.35
# MEAN Train accuracy for tied23: 3.11
# MEAN Test accuracy for tied23: 2.95
# MEAN Train accuracy for tied20: 3.43
# MEAN Test accuracy for tied20: 3.27
# MEAN Train accuracy for tied21: 3.43
# MEAN Test accuracy for tied21: 3.11
# MEAN Train accuracy for tied26: 7.39
# MEAN Test accuracy for tied26: 9.17
# MEAN Train accuracy for tied27: 2.99
# MEAN Test accuracy for tied27: 3.27
# MEAN Train accuracy for tied24: 1.29
# MEAN Test accuracy for tied24: 0.65
# MEAN Train accuracy for tied25: 4.44
# MEAN Test accuracy for tied25: 4.42
# MEAN Train accuracy for tied28: 3.07
# MEAN Test accuracy for tied28: 3.44
# MEAN Train accuracy for tied29: 4.12
# MEAN Test accuracy for tied29: 4.26
# MEAN Train accuracy for spherical33: 1.66
# MEAN Test accuracy for spherical33: 1.31
# MEAN Train accuracy for spherical32: 2.22
# MEAN Test accuracy for spherical32: 1.96
# MEAN Train accuracy for spherical31: 1.82
# MEAN Test accuracy for spherical31: 2.13
# MEAN Train accuracy for spherical30: 3.68
# MEAN Test accuracy for spherical30: 4.09
# MEAN Train accuracy for spherical37: 1.66
# MEAN Test accuracy for spherical37: 1.47
# MEAN Train accuracy for spherical36: 5.37
# MEAN Test accuracy for spherical36: 4.09
# MEAN Train accuracy for spherical35: 3.39
# MEAN Test accuracy for spherical35: 3.11
# MEAN Train accuracy for spherical34: 1.49
# MEAN Test accuracy for spherical34: 1.15
# MEAN Train accuracy for spherical39: 2.75
# MEAN Test accuracy for spherical39: 2.95
# MEAN Train accuracy for spherical38: 6.38
# MEAN Test accuracy for spherical38: 7.36
# MEAN Train accuracy for tied31: 1.86
# MEAN Test accuracy for tied31: 1.80
# MEAN Train accuracy for diag49: 3.60
# MEAN Test accuracy for diag49: 3.60
# MEAN Train accuracy for diag48: 5.33
# MEAN Test accuracy for diag48: 4.91
# MEAN Train accuracy for diag47: 2.46
# MEAN Test accuracy for diag47: 2.78
# MEAN Train accuracy for diag46: 1.17
# MEAN Test accuracy for diag46: 1.15
# MEAN Train accuracy for diag45: 13.86
# MEAN Test accuracy for diag45: 14.73
# MEAN Train accuracy for diag44: 2.59
# MEAN Test accuracy for diag44: 2.45
# MEAN Train accuracy for diag43: 2.02
# MEAN Test accuracy for diag43: 2.95
# MEAN Train accuracy for diag42: 11.88
# MEAN Test accuracy for diag42: 10.15
# MEAN Train accuracy for diag41: 1.21
# MEAN Test accuracy for diag41: 0.49
# MEAN Train accuracy for diag40: 1.58
# MEAN Test accuracy for diag40: 0.98
# MEAN Train accuracy for spherical46: 2.79
# MEAN Test accuracy for spherical46: 3.27
# MEAN Train accuracy for spherical47: 2.34
# MEAN Test accuracy for spherical47: 2.13
# MEAN Train accuracy for spherical44: 2.91
# MEAN Test accuracy for spherical44: 2.78
# MEAN Train accuracy for spherical45: 7.52
# MEAN Test accuracy for spherical45: 8.51
# MEAN Train accuracy for spherical42: 5.49
# MEAN Test accuracy for spherical42: 5.40
# MEAN Train accuracy for spherical43: 3.64
# MEAN Test accuracy for spherical43: 3.76
# MEAN Train accuracy for spherical40: 2.83
# MEAN Test accuracy for spherical40: 2.62
# MEAN Train accuracy for spherical41: 3.43
# MEAN Test accuracy for spherical41: 3.93
# MEAN Train accuracy for tied39: 3.11
# MEAN Test accuracy for tied39: 3.44
# MEAN Train accuracy for tied35: 2.95
# MEAN Test accuracy for tied35: 3.27
# MEAN Train accuracy for full23: 2.99
# MEAN Test accuracy for full23: 3.60
# MEAN Train accuracy for spherical48: 4.65
# MEAN Test accuracy for spherical48: 3.27
# MEAN Train accuracy for spherical49: 1.62
# MEAN Test accuracy for spherical49: 1.96
# MEAN Train accuracy for spherical20: 2.67
# MEAN Test accuracy for spherical20: 2.45
# MEAN Train accuracy for spherical21: 2.87
# MEAN Test accuracy for spherical21: 2.95
# MEAN Train accuracy for spherical22: 6.99
# MEAN Test accuracy for spherical22: 6.55
# MEAN Train accuracy for spherical23: 3.52
# MEAN Test accuracy for spherical23: 3.60
# MEAN Train accuracy for spherical24: 1.13
# MEAN Test accuracy for spherical24: 1.31
# MEAN Train accuracy for spherical25: 4.97
# MEAN Test accuracy for spherical25: 3.44
# MEAN Train accuracy for spherical26: 10.71
# MEAN Test accuracy for spherical26: 9.82
# MEAN Train accuracy for spherical27: 3.56
# MEAN Test accuracy for spherical27: 3.76
# MEAN Train accuracy for spherical28: 2.67
# MEAN Test accuracy for spherical28: 3.11
# MEAN Train accuracy for spherical29: 4.69
# MEAN Test accuracy for spherical29: 3.27
# MEAN Train accuracy for tied36: 4.53
# MEAN Test accuracy for tied36: 4.91
# MEAN Train accuracy for full18: 3.03
# MEAN Test accuracy for full18: 3.60
# MEAN Train accuracy for full19: 2.91
# MEAN Test accuracy for full19: 3.60
# MEAN Train accuracy for tied38: 6.59
# MEAN Test accuracy for tied38: 6.87
# MEAN Train accuracy for full12: 4.24
# MEAN Test accuracy for full12: 4.58
# MEAN Train accuracy for full13: 2.99
# MEAN Test accuracy for full13: 3.60
# MEAN Train accuracy for full10: 3.19
# MEAN Test accuracy for full10: 3.60
# MEAN Train accuracy for full11: 3.31
# MEAN Test accuracy for full11: 3.60
# MEAN Train accuracy for full16: 2.10
# MEAN Test accuracy for full16: 2.29
# MEAN Train accuracy for full17: 2.95
# MEAN Test accuracy for full17: 3.60
# MEAN Train accuracy for full14: 2.87
# MEAN Test accuracy for full14: 3.60
# MEAN Train accuracy for full15: 45.94
# MEAN Test accuracy for full15: 45.01
# MEAN Train accuracy for diag38: 49.29
# MEAN Test accuracy for diag38: 52.21
# MEAN Train accuracy for diag39: 44.77
# MEAN Test accuracy for diag39: 45.66
# MEAN Train accuracy for diag32: 2.46
# MEAN Test accuracy for diag32: 1.80
# MEAN Train accuracy for diag33: 1.49
# MEAN Test accuracy for diag33: 0.98
# MEAN Train accuracy for diag30: 10.06
# MEAN Test accuracy for diag30: 10.47
# MEAN Train accuracy for diag31: 44.97
# MEAN Test accuracy for diag31: 46.64
# MEAN Train accuracy for diag36: 3.80
# MEAN Test accuracy for diag36: 3.44
# MEAN Train accuracy for diag37: 44.97
# MEAN Test accuracy for diag37: 46.48
# MEAN Train accuracy for diag34: 1.17
# MEAN Test accuracy for diag34: 1.31
# MEAN Train accuracy for diag35: 2.42
# MEAN Test accuracy for diag35: 1.47
# MEAN Train accuracy for diag2: 2.02
# MEAN Test accuracy for diag2: 1.96
# MEAN Train accuracy for diag3: 2.42
# MEAN Test accuracy for diag3: 1.15
# MEAN Train accuracy for diag0: 9.90
# MEAN Test accuracy for diag0: 9.66
# MEAN Train accuracy for diag1: 1.21
# MEAN Test accuracy for diag1: 0.82
# MEAN Train accuracy for diag6: 1.62
# MEAN Test accuracy for diag6: 1.47
# MEAN Train accuracy for diag7: 2.91
# MEAN Test accuracy for diag7: 3.27
# MEAN Train accuracy for diag4: 10.95
# MEAN Test accuracy for diag4: 11.13
# MEAN Train accuracy for diag5: 1.54
# MEAN Test accuracy for diag5: 1.47
# MEAN Train accuracy for diag8: 1.17
# MEAN Test accuracy for diag8: 2.13
# MEAN Train accuracy for diag9: 20.32
# MEAN Test accuracy for diag9: 19.80
# MEAN Train accuracy for spherical15: 48.65
# MEAN Test accuracy for spherical15: 50.08
# MEAN Train accuracy for spherical14: 2.67
# MEAN Test accuracy for spherical14: 2.78
# MEAN Train accuracy for spherical17: 2.38
# MEAN Test accuracy for spherical17: 2.13
# MEAN Train accuracy for spherical16: 2.42
# MEAN Test accuracy for spherical16: 2.29
# MEAN Train accuracy for spherical11: 11.27
# MEAN Test accuracy for spherical11: 10.47
# MEAN Train accuracy for spherical10: 10.79
# MEAN Test accuracy for spherical10: 9.82
# MEAN Train accuracy for spherical13: 2.59
# MEAN Test accuracy for spherical13: 2.29
# MEAN Train accuracy for spherical12: 4.89
# MEAN Test accuracy for spherical12: 3.44
# MEAN Train accuracy for spherical19: 2.67
# MEAN Test accuracy for spherical19: 2.29
# MEAN Train accuracy for spherical18: 2.42
# MEAN Test accuracy for spherical18: 2.62
# MEAN Train accuracy for diag29: 46.51
# MEAN Test accuracy for diag29: 46.64
# MEAN Train accuracy for diag28: 1.82
# MEAN Test accuracy for diag28: 0.98
# MEAN Train accuracy for diag21: 1.01
# MEAN Test accuracy for diag21: 1.47
# MEAN Train accuracy for diag20: 1.82
# MEAN Test accuracy for diag20: 1.15
# MEAN Train accuracy for diag23: 1.70
# MEAN Test accuracy for diag23: 0.98
# MEAN Train accuracy for diag22: 8.24
# MEAN Test accuracy for diag22: 9.33
# MEAN Train accuracy for diag25: 46.79
# MEAN Test accuracy for diag25: 47.46
# MEAN Train accuracy for diag24: 0.65
# MEAN Test accuracy for diag24: 0.98
# MEAN Train accuracy for diag27: 12.32
# MEAN Test accuracy for diag27: 11.13
# MEAN Train accuracy for diag26: 19.68
# MEAN Test accuracy for diag26: 19.31
# MEAN Train accuracy for tied19: 3.19
# MEAN Test accuracy for tied19: 3.76
# MEAN Train accuracy for tied18: 2.99
# MEAN Test accuracy for tied18: 3.27
# MEAN Train accuracy for tied13: 3.11
# MEAN Test accuracy for tied13: 3.11
# MEAN Train accuracy for tied12: 4.40
# MEAN Test accuracy for tied12: 4.42
# MEAN Train accuracy for tied11: 3.35
# MEAN Test accuracy for tied11: 3.60
# MEAN Train accuracy for tied10: 3.27
# MEAN Test accuracy for tied10: 3.44
# MEAN Train accuracy for tied17: 3.03
# MEAN Test accuracy for tied17: 3.27
# MEAN Train accuracy for tied16: 3.11
# MEAN Test accuracy for tied16: 3.11
# MEAN Train accuracy for tied15: 49.66
# MEAN Test accuracy for tied15: 49.59
# MEAN Train accuracy for tied14: 3.07
# MEAN Test accuracy for tied14: 3.27
# MEAN Train accuracy for full34: 2.51
# MEAN Test accuracy for full34: 2.13
# MEAN Train accuracy for full35: 2.67
# MEAN Test accuracy for full35: 3.60
# MEAN Train accuracy for full36: 4.44
# MEAN Test accuracy for full36: 4.42
# MEAN Train accuracy for full37: 2.67
# MEAN Test accuracy for full37: 2.13
# MEAN Train accuracy for full30: 2.87
# MEAN Test accuracy for full30: 3.60
# MEAN Train accuracy for full31: 1.78
# MEAN Test accuracy for full31: 1.64
# MEAN Train accuracy for full32: 1.66
# MEAN Test accuracy for full32: 2.29
# MEAN Train accuracy for full33: 3.19
# MEAN Test accuracy for full33: 1.96
# MEAN Train accuracy for full38: 7.27
# MEAN Test accuracy for full38: 8.02
# MEAN Train accuracy for full39: 3.03
# MEAN Test accuracy for full39: 3.60
# MEAN Train accuracy for diag14: 1.37
# MEAN Test accuracy for diag14: 0.98
# MEAN Train accuracy for diag15: 3.56
# MEAN Test accuracy for diag15: 3.11
# MEAN Train accuracy for diag16: 3.23
# MEAN Test accuracy for diag16: 3.76
# MEAN Train accuracy for diag17: 1.58
# MEAN Test accuracy for diag17: 1.15
# MEAN Train accuracy for diag10: 9.25
# MEAN Test accuracy for diag10: 9.33
# MEAN Train accuracy for diag11: 44.48
# MEAN Test accuracy for diag11: 45.50
# MEAN Train accuracy for diag12: 3.15
# MEAN Test accuracy for diag12: 2.95
# MEAN Train accuracy for diag13: 1.66
# MEAN Test accuracy for diag13: 2.29
# MEAN Train accuracy for diag18: 2.26
# MEAN Test accuracy for diag18: 1.96
# MEAN Train accuracy for diag19: 2.22
# MEAN Test accuracy for diag19: 1.31
# MEAN Train accuracy for tied9: 7.64
# MEAN Test accuracy for tied9: 9.00
# MEAN Train accuracy for tied8: 2.42
# MEAN Test accuracy for tied8: 1.64
# MEAN Train accuracy for tied3: 3.35
# MEAN Test accuracy for tied3: 4.09
# MEAN Train accuracy for tied2: 3.03
# MEAN Test accuracy for tied2: 3.93
# MEAN Train accuracy for tied1: 3.07
# MEAN Test accuracy for tied1: 3.11
# MEAN Train accuracy for tied0: 2.63
# MEAN Test accuracy for tied0: 3.76
# MEAN Train accuracy for tied7: 3.07
# MEAN Test accuracy for tied7: 3.11
# MEAN Train accuracy for tied6: 2.91
# MEAN Test accuracy for tied6: 3.11
# MEAN Train accuracy for tied5: 2.10
# MEAN Test accuracy for tied5: 1.15
# MEAN Train accuracy for tied4: 4.40
# MEAN Test accuracy for tied4: 4.91

# %%
from sklearn.metrics import confusion_matrix
classifiers['diag38'].fit(X_train, t_train)
train_preds = classifiers['diag38'].predict(X_train)
pd.DataFrame(confusion_matrix(t_train, train_preds),columns=util.malware_classes,index=util.malware_classes)
# Out:
#            Agent  AutoRun  FraudLoad  FraudPack  Hupigon  Krap  Lipler  \
# Agent         33       42          2          0        0     1       0
# AutoRun        2        6          0          0        0     0       0
# FraudLoad      4       14          0          0        0     0       0
# FraudPack      4        4          0          0        0     0       0
# Hupigon        7       12          0          0        0     0       0
# Krap           2       31          0          0        0     0       0
# Lipler         0       51          0          0        0     0       0
# Magania       30        6          0          0        0     0       0
# None         388      199          0        953        2     6       4
# Poison        16        0          0          0        0     0       0
# Swizzor      308        2          0          0        0   144       0
# Tdss           7        1          0          0        0     0       0
# VB           260       14          0          0        0     0       0
# Virut         46        8          0          0        0     0       0
# Zbot           9        0          2          0        0     0       0
#
#            Magania  None  Poison  Swizzor  Tdss  VB  Virut  Zbot
# Agent            0     7       0        3    17   0      9     0
# AutoRun          0    32       0        1     7   0      2     0
# FraudLoad        0     2       0        0     6   0     11     0
# FraudPack        0     7       0        0    17   0      0     0
# Hupigon          0    15       0        0     2   0      5     0
# Krap             0     2       0        0     4   0      0     0
# Lipler           0     1       0        0     1   0      0     0
# Magania          0     4       0        0     1   0      0     0
# None             1    25       1        0    13   1     16     0
# Poison           0     3       0        1     1   0      0     0
# Swizzor          0    88       0        0     0   0      0     0
# Tdss             0    22       0        0     2   0      0     0
# VB               0    96       0        2     2   0      2     0
# Virut            0     2       0        0     1   0      2     0
# Zbot             0     0       0       29     0   0      0     0

# %%
train_preds = log_l2_best.predict(X_train)
pd.DataFrame(confusion_matrix(t_train, train_preds),columns=util.malware_classes,index=util.malware_classes)

# %% [markdown]
# Good Random_states
# 0:
# MEAN Train accuracy for diag: 9.90
# MEAN Test accuracy for diag: 9.66
#
#
# What is EM iteratating to find if y is known???
# After cross validation, fit on entire training set before predicting on test set?

# %%
import confusion.

train_preds=log_12_best.predict(X_train
                               pd.DataFrame(confusion_matrix(t_train, train_preds), columns=util.malware_classes,index=util.malware_class))
